# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
salary = int(input("Enter your salary "))
years_of_service = int(input("Enter your years of service "))
bonus = 5
net_bonus = (5/100)*salary
if(years_of_service > 5):
    print("You are eligible for 5% bonus")
    print("the net bonus amout is ",net_bonus)
else:
    print("Sorry!!you are not eligible for bonus")
# Out:
# You are eligible for 5% bonus
# the net bonus amout is  50.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here
age = int(input("Enter your age : "))
if(age > 17):
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Eligible

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here
number = int(input("Enter your number : "))
if(number % 2 == 0):
    print("Even Number")
else:
    print("Odd number")
# Out:
# Odd number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here
number = int(input("Enter a number : "))
if(number % 7 == 0):
    print("The number you entered is divisible by 7")
else:
    print("this number is not divisible by 7")
# Out:
# this number is nit divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here
number =  int(input("enter a number : "))
if(number % 5 == 0):
    print("Hello !!")
else:
    print("Bye")
# Out:
# Bye

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here
num = int(input("Enter a number: "))
last_digit = num % 10
print("Last digit is:", last_digit)
# Out:
# Last digit is: 0

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 
length = int(input("Enter the length : "))
breath = int(input("Enter the breath : "))
if(length == breath):
    print("It is a square")
else:
    print("It is a rectangle")
# Out:
# It is a rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here
a = int(input("Enter the first value : "))
b = int(input("Enter the second value : "))
if(a > b):
    print(" a is greater than b")
elif(a == b):
    print("a and b are equal")
else:
    print("b is greater than a")
# Out:
#  a is greater than b

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here
quantity = int(input("Enter the quantity : "))
unit_cost = 100
purchased_cost = (quantity * unit_cost)
 
if(purchased_cost > 1000):
    discount = (10/100)*purchased_cost
    after_discount_price = purchased_cost - discount
    print("After the discount your total cost is $",after_discount_price)
else:
    print("your total cost is $",purchased_cost)
# Out:
# After the discount your total cost is $ 990.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
marks = int(input("Enter your marks : "))
if(marks > 80):
    print("A")
elif(marks > 60 and marks <= 80):
    print("B")
elif(marks > 50 and marks <= 60):
    print("C")    
elif(marks > 45 and marks <= 50):
    print("D")
elif(marks >= 25 and marks <= 45):
    print("E")
elif(marks < 25):
    print("F")
# Out:
# E

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here
total_classes = int(input("enter the total number of classes held : "))
classes_attended = int(input("Enter the classes attended : "))
percentage_attendclasses = (classes_attended/total_classes) * 100

if(percentage_attendclasses<=75):
    print("You are not allowed to sit in the exam")
else:
    print("You are allowed to give the exam !!")
# Out:
# You are allowed to give the exam !!

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here
total_classes = int(input("enter the total number of classes held : "))
classes_attended = int(input("Enter the classes attended : "))
percentage_attendclasses = (classes_attended/total_classes) * 100

if(percentage_attendclasses<75):
    print("Due to attendence you are not allowed but if you have a medical cause you will be allowed")
    medical_cause =input("Do you have a medical reason ??(Y/N)")
    if(medical_cause == 'Y'):
        print("You can give exam")
    else:
        print("You are NOT allowed to give the exam !!")
else:
    print("You are allowed to give the exam !!")
# Out:
# You are allowed to give the exam !!

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here 
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("It is a leap year")
else:
    print("It is not a leap year")
# Out:
# It is not a leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
age = int(input("Enter your age : "))
gender = input("Enter your gender (M/F): ")
marital_status = input("Enter your marital status (Y/N) : ")

if(gender == 'F'):
    print("Females can only work in urban areas")
elif(gender == 'M' and age >20 and age<40):
    print("You can work anywhere")
elif(gender == 'M' and age >40 and age<60):
    print("You can work only in urban areas")
elif(age < 20 or age > 60): 
    print("Error")
# Out:
# You can work only in urban areas

# %% [markdown]
# 18) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
units = int(input("Enter number of units: "))

bill = 0

# Calculation
if units <= 100:
    bill = 0

elif units <= 300:
    bill = (units - 100) * 5

else:
    bill = (200 * 5) + (units - 300) * 10

# Output
print("Total bill is Rs.", bill)
# Out:
# Total bill is Rs. 250

# %% [markdown]
# 19) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here

age1 = int(input("Enter age of first person: "))
age2 = int(input("Enter age of second person: "))
age3 = int(input("Enter age of third person: "))

oldest = age1
youngest = age1
oldest_person = "First Person"
youngest_person = "First Person"

if age2 > oldest:
    oldest = age2
    oldest_person = "Second Person"

if age3 > oldest:
    oldest = age3
    oldest_person = "Third Person"

if age2 < youngest:
    youngest = age2
    youngest_person = "Second Person"

if age3 < youngest:
    youngest = age3
    youngest_person = "Third Person"

print(oldest_person, "is the oldest with age", oldest)
print(youngest_person, "is the youngest with age", youngest)
# Out:
# Third Person is the oldest with age 30
# First Person is the youngest with age 10
