# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name: Talal Iqbal\nFather name: Pervaiz Iqbal\nDate of birth: 01-05-2005")
# Out:
# Name: Talal Iqbal
# Father name: Pervaiz Iqbal
# Date of birth: 01-05-2005

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Write your code here
name = "talal iqbal"
age = 20
height = 5.9
print("My name is : ",name)
print("My age is : ",age)
print("My height is : ",height)
# Out:
# My name is :  talal iqbal
# My age is :  20
# My height is :  5.9

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Write your code here

a = 10
b = 5

# 1. Arithmetic Operators
print("Arithmetic Operators:")
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Exponent:", a ** b)

# 2. Comparison Operators
print("\nComparison Operators:")
print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)

# 3. Logical Operators
print("\nLogical Operators:")
print("a > 5 and b < 10:", a > 5 and b < 10)
print("a > 5 or b > 10:", a > 5 or b > 10)
print("not(a > b):", not(a > b))

# 4. Assignment Operators
print("\nAssignment Operators:")
c = a
c += b
print("c += b:", c)
c -= b
print("c -= b:", c)
c *= b
print("c *= b:", c)
c /= b
print("c /= b:", c)
# Out:
# Arithmetic Operators:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Modulus: 0
# Exponent: 100000
#
# Comparison Operators:
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False
#
# Logical Operators:
# a > 5 and b < 10: True
# a > 5 or b > 10: True
# not(a > b): False
#
# Assignment Operators:
# c += b: 15
# c -= b: 10
# c *= b: 50
# c /= b: 10.0

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Write your code here
English = 90
Maths = 78
Islamiat = 88
total_marks = 300
obtained_marks = English + Maths + Islamiat

percentage = (obtained_marks/total_marks)*100
print(f"your obtained marks are {obtained_marks} and your percentage is {percentage}")
# Out:
# your obtained marks are 256 and your percentage is 85.33333333333334
